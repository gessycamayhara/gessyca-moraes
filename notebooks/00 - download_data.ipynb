# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/data.csv")
df.head()
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 0              0.88                    18                     70
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# ...

# %%
df.to_csv("../data/raw/data.csv", index=False)

# %%
dicionario = pd.DataFrame([
    {
        "variavel": "Age",
        "descricao": "Indica a idade do sujeito de teste.",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },{
        "variavel": "Gender",
        "descricao": "Indica o gênero do sujeito de teste.",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },{
        "variavel": "Bedtime",
        "descricao": "Indica a data e horário que o sujeito de teste foi para a cama.",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },{
        "variavel": "Wakeup time",
        "descricao": "Indica a data e o horário em que o sujeito de teste acordou.",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },{
        "variavel": "Sleep duration",
        "descricao": "Indica a duração do sono.",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },{
        "variavel": "Sleep efficiency",
        "descricao": "Indica a eficiência do sono.",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },{
        "variavel": "REM sleep percentage",
        "descricao": "Indica a porcentagem do estágio do sono REM.",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },{
        "variavel": "Deep sleep percentage",
        "descricao": "Indica a porcentagem do estágio de sono profundo.",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },{
        "variavel": "Light sleep percentage",
        "descricao": "Indica a porcentagem do estágio de sono leve.",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },{
        "variavel": "Awakenings",
        "descricao": "Indica a quantidade de vezes que o sujeito de teste acordou durante a noite.",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },{
        "variavel": "Caffeine consumption",
        "descricao": "Indica a quantidade de cafeína consumida nas últimas 24 horas antes de ir para a cama.",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },{
        "variavel": "Alcohol consumption",
        "descricao": "Indica a quantidade de álcool consumido nas últimas 24 horas antes de ir para a cama.",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },{
        "variavel": "Smoking status",
        "descricao": "Indica se é fumante ou não.",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },{
        "variavel": "Exercise frequency",
        "descricao": "Indica a frequÊncia de exercícios físicos",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    }
])
dicionario
# Out:
#                   variavel                                          descricao  \
# 0                      Age                Indica a idade do sujeito de teste.
# 1                   Gender               Indica o gênero do sujeito de teste.
# 2                  Bedtime  Indica a data e horário que o sujeito de teste...
# 3              Wakeup time  Indica a data e o horário em que o sujeito de ...
# 4           Sleep duration                          Indica a duração do sono.
# 5         Sleep efficiency                       Indica a eficiência do sono.
# 6     REM sleep percentage       Indica a porcentagem do estágio do sono REM.
# 7    Deep sleep percentage  Indica a porcentagem do estágio de sono profundo.
# 8   Light sleep percentage      Indica a porcentagem do estágio de sono leve.
# 9               Awakenings  Indica a quantidade de vezes que o sujeito de ...
# 10    Caffeine consumption  Indica a quantidade de cafeína consumida nas ú...
# ...
